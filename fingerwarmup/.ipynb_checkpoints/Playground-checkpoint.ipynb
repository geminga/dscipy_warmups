# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dicethrows = list = [1,82,100,61,12,93,98,89,30,38,15,28,5,77]

# %%
plt.hist(dicethrows, bins=10)
plt.ylabel('No of times')
plt.show()

# %%
sns.distplot(dicethrows);
